# %%
import os
from train import Trainer

# %%
trainer = Trainer()
gpus = "0,1"
os.environ['CUDA_VISIBLE_DEVICES'] = gpus
nr_gpus = len(gpus.split(','))
trainer.run(nr_gpus)
# Out:
# ['data/Train/512x512_256x256_dist/']
# ['data/Valid/512x512_256x256_dist/']
# [262, 262] [256, 256]
# [0503 19:00:14 @parallel.py:293] [PrefetchDataZMQ] Will fork a dataflow more than one times. This assumes the datapoints are i.i.d.
# [262, 262] [256, 256]
# [0503 19:00:14 @logger.py:73] Argv: /cvdata2/anaconda3/envs/haichuan-ccRCC/lib/python3.6/site-packages/ipykernel_launcher.py -f /home/haichuan/.local/share/jupyter/runtime/kernel-64072433-d826-4d55-87f2-2bb5b687fd6b.json
# ['data/Train/512x512_256x256_dist/']
# ['data/Valid/512x512_256x256_dist/']
# ['data/Train/512x512_256x256_dist/']
# ['data/Valid/512x512_256x256_dist/']
# [0503 19:00:14 @training.py:52] [DataParallel] Training a model of 2 towers.
# [0503 19:00:14 @interface.py:34] Automatically applying QueueInput on the DataFlow.
# [0503 19:00:14 @interface.py:46] Automatically applying StagingInput on the DataFlow.
# ...
